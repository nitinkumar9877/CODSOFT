# %% [markdown]
# # IMPORTING LIBARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("advertising.csv")
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %% [markdown]
# # INITIAL PROCESSING OF DATASET

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df.tail()
# Out:
#         TV  Radio  Newspaper  Sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4

# %%
df.shape
# Out:
# (200, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df.dtypes
# Out:
# TV           float64
# Radio        float64
# Newspaper    float64
# Sales        float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
df.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %% [markdown]
# # SALES RELATION WITH RESPECT TO EACH ATTRIBUTE USING SCATTER PLOT

# %%
sns.set()
sns.pairplot(df, x_vars=['TV', 'Newspaper', 'Radio'], y_vars='Sales', height=6, aspect=1, kind='scatter')
plt.show()
# observation
# Its clear rom the scatter plot of tv that when we increases the cost of tv ads the sale

# %%
sns.set
# Out:
# <function seaborn.rcmod.set(*args, **kwargs)>

# %% [markdown]
# # HISTOGRAM

# %%
df['Radio'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Newspaper'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['TV'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Let's see the correlation between different variables.
sns.heatmap(df.corr(), cmap="crest", annot = True)
plt.show()

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %% [markdown]
# # COLLECTIVE ANALYSIS

# %%
# Plotting the grouped bar chart directly from the DataFrame
ax = df[['TV', 'Newspaper', 'Radio']].plot(kind='bar', width=5)

# Set labels and title
ax.set_xlabel('Index')
ax.set_ylabel('Sales')
ax.set_title('Sales for TV, Newspaper, and Radio')
# Show the plot
plt.show()

# %% [markdown]
# # MACHINE LEARNING ALGORITHM

# %% [markdown]
# # IMPORTING LIBRARY FOR TRAIN AND TEST MODEL

# %%
from sklearn.model_selection import train_test_split
X=df.drop(columns='Sales')
Y=df['Sales']
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=3)

# %%
from sklearn.linear_model import  LinearRegression
model=LinearRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # LinearRegression()
#
# In a Jupyter environment, please rerun this cell to show the HTML representation or trust the notebook.
# On GitHub, the HTML representation is unable to render, please try loading this page with nbviewer.org.

# %%
prediction=model.predict(X_test)

# %%
prediction
# Out:
# array([17.94221632, 11.28731032, 19.36406753, 15.25309499,  8.85035488,
#        11.08345095, 24.54827272, 10.72184726, 18.64190205, 17.03877174,
#        14.71887065, 13.30204368, 19.10529921, 11.4654086 , 13.82417942,
#        14.56139355, 16.86156735, 17.27369971, 17.78634747, 21.28201581,
#        19.1397699 , 11.05346066,  9.93276334, 11.49854807,  8.5309559 ,
#        13.26073545, 21.75566382, 16.96066432, 24.25791572, 11.92392893,
#        16.40376866, 21.96064207,  9.51770237, 10.16209996, 10.08141197,
#        10.45644324, 15.54919097,  9.92133897, 13.83425453, 12.54320065,
#        14.5093965 , 12.61758414,  6.46804914, 20.25656292, 23.16303373,
#        24.65508581, 15.20817964,  9.27513655, 18.72004324, 18.16217728,
#        12.73063894, 16.65175796, 15.79776032,  8.36188762, 21.22771856,
#         9.52094834, 23.88078008, 23.29062902, 19.6930198 , 16.76467522])

# %%
model.intercept_
#In linear regression, the intercept_ attribute of the model represents the estimated val
# Out:
# 5.022730805826264

# %%
model.coef_
#In linear regression, the coef_ attribute of the model represents the coefficients or we
# Out:
# array([ 0.05223455,  0.10672463, -0.00120158])

# %% [markdown]
# # PREDICTION USING ACCURACY

# %%
accuracy_score=model.score(X_test,Y_test)*100

print(f"Accuracy of model: {accuracy_score}%")
# Out:
# Accuracy of model: 88.77675297095178%
